# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic_data_updated.csv')

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1       no  third
# 1            2      yes  first
# 2            3      yes  third
# 3            4      yes  first
# 4            5       no  third
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Multivariate Analysis

# %%
sns.countplot(x=df['Sex'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
gender_split = df.groupby('Sex')['Survived'].value_counts(normalize=True)

print(gender_split)
# Out:
# Sex     Survived
# female  yes         0.742038
#         no          0.257962
# male    no          0.811092
#         yes         0.188908
# Name: proportion, dtype: float64

# %%
sns.countplot(x=df['Pclass'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
pclass_split = df.groupby('Pclass')['Survived'].value_counts(normalize=True)

print(pclass_split)
# Out:
# Pclass  Survived
# first   yes         0.629630
#         no          0.370370
# second  no          0.527174
#         yes         0.472826
# third   no          0.757637
#         yes         0.242363
# Name: proportion, dtype: float64

# %% [markdown]
# # Multi Variate Analysis ( Barplot for Cat-Num)

# %%
sns.barplot(x=df['Pclass'], y=df['Fare'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x=df['Survived'],y=df['Age'],hue=df['Sex'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.barplot(x=df['Survived'],y=df['Age'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.kdeplot(data = df, x = 'Age', hue = 'Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=df, x = 'total_bill', y = 'tip', hue = 'sex', size = 'size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # y data profiling

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- -------------------
# aiobotocore                       2.19.0
# aiohappyeyeballs                  2.4.4
# aiohttp                           3.11.10
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# altair                            5.5.0
# anaconda-anon-usage               0.7.1
# anaconda-auth                     0.8.6
# anaconda-catalogs                 0.2.0
# anaconda-cli-base                 0.5.2
# anaconda-client                   1.13.0
# anaconda-navigator                2.6.6
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# anyio                             4.7.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.3.0
# astroid                           3.3.8
# astropy                           7.0.0
# astropy-iers-data                 0.2025.1.13.0.34.51
# asttokens                         3.0.0
# async-lru                         2.0.4
# asyncssh                          2.17.0
# atomicwrites                      1.4.0
# attrs                             24.3.0
# Automat                           24.8.1
# autopep8                          2.0.4
# babel                             2.16.0
# bcrypt                            4.3.0
# beautifulsoup4                    4.12.3
# binaryornot                       0.4.4
# black                             24.10.0
# bleach                            6.2.0
# blinker                           1.9.0
# bokeh                             3.6.2
# boltons                           24.1.0
# botocore                          1.36.3
# Bottleneck                        1.4.2
# branca                            0.8.2
# Brotli                            1.0.9
# cachetools                        5.5.1
# certifi                           2025.4.26
# cffi                              1.17.1
# chardet                           4.0.0
# charset-normalizer                3.3.2
# click                             8.1.8
# cloudpickle                       3.0.0
# colorama                          0.4.6
# colorcet                          3.1.0
# comm                              0.2.1
# conda                             25.5.1
# conda-anaconda-telemetry          0.1.2
# conda-anaconda-tos                0.2.0
# conda-build                       25.5.0
# conda-content-trust               0.2.0
# conda_index                       0.6.1
# conda-libmamba-solver             25.4.0
# conda-pack                        0.7.1
# conda-package-handling            2.4.0
# conda_package_streaming           0.11.0
# conda-repo-cli                    1.0.165
# conda-token                       0.6.0
# constantly                        23.10.4
# contourpy                         1.3.1
# cookiecutter                      1.7.3
# cryptography                      44.0.1
# cssselect                         1.2.0
# cycler                            0.11.0
# cytoolz                           1.0.1
# dask                              2025.2.0
# dask-expr                         2.0.0
# datashader                        0.18.0
# debugpy                           1.8.11
# decorator                         5.1.1
# defusedxml                        0.7.1
# Deprecated                        1.2.13
# diff-match-patch                  20200713
# dill                              0.3.8
# distributed                       2025.2.0
# distro                            1.9.0
# docstring-to-markdown             0.11
# docutils                          0.21.2
# et_xmlfile                        1.1.0
# evalidate                         2.0.3
# executing                         0.8.3
# fastjsonschema                    2.20.0
# filelock                          3.17.0
# flake8                            7.1.1
# Flask                             3.1.0
# folium                            0.20.0
# fontawesomefree                   6.6.0
# fonttools                         4.55.3
# fqdn                              1.5.1
# frozendict                        2.4.2
# frozenlist                        1.5.0
# fsspec                            2025.3.2
# gitdb                             4.0.7
# GitPython                         3.1.43
# gmpy2                             2.2.1
# greenlet                          3.1.1
# h11                               0.16.0
# h5py                              3.12.1
# HeapDict                          1.0.1
# holoviews                         1.20.2
# httpcore                          1.0.9
# httpx                             0.28.1
# hvplot                            0.11.3
# hyperlink                         21.0.0
# idna                              3.7
# imageio                           2.37.0
# imagesize                         1.4.1
# imbalanced-learn                  0.13.0
# importlib_metadata                8.5.0
# incremental                       24.7.2
# inflection                        0.5.1
# iniconfig                         1.1.1
# intake                            2.0.7
# intervaltree                      3.1.0
# ipykernel                         6.29.5
# ipython                           8.30.0
# ipywidgets                        8.1.5
# isoduration                       20.11.0
# isort                             6.0.1
# itemadapter                       0.3.0
# itemloaders                       1.3.2
# itsdangerous                      2.2.0
# jaraco.classes                    3.2.1
# jaraco.context                    0.0.0
# jaraco.functools                  4.1.0
# jedi                              0.19.2
# jellyfish                         1.1.3
# Jinja2                            3.1.6
# jinja2-time                       0.2.0
# jmespath                          1.0.1
# joblib                            1.4.2
# json5                             0.9.25
# jsonpatch                         1.33
# jsonpointer                       2.1
# jsonschema                        4.23.0
# jsonschema-specifications         2023.7.1
# jupyter                           1.1.1
# jupyter_client                    8.6.3
# jupyter-console                   6.6.3
# jupyter_core                      5.7.2
# jupyter-events                    0.12.0
# jupyter-lsp                       2.2.5
# jupyter_server                    2.15.0
# jupyter_server_terminals          0.5.3
# jupyterlab                        4.3.4
# jupyterlab_kernelspy              4.0.0
# jupyterlab-lsp                    5.3.0
# jupyterlab_pygments               0.3.0
# jupyterlab_server                 2.27.3
# jupyterlab_widgets                3.0.13
# keyring                           25.6.0
# kiwisolver                        1.4.8
# lazy_loader                       0.4
# lckr_jupyterlab_variableinspector 3.2.4
# libarchive-c                      5.1
# libmambapy                        2.0.5
# lief                              0.16.4
# linkify-it-py                     2.0.0
# llvmlite                          0.44.0
# lmdb                              1.6.2
# locket                            1.0.0
# lxml                              5.3.0
# lz4                               4.3.2
# Markdown                          3.8
# markdown-it-py                    2.2.0
# MarkupSafe                        3.0.2
# matplotlib                        3.10.0
# matplotlib-inline                 0.1.6
# mccabe                            0.7.0
# mdit-py-plugins                   0.3.0
# mdurl                             0.1.0
# menuinst                          2.2.0
# mistune                           3.1.2
# mkl_fft                           1.3.11
# mkl_random                        1.2.8
# mkl-service                       2.4.0
# more-itertools                    10.3.0
# mpmath                            1.3.0
# msgpack                           1.0.3
# multidict                         6.1.0
# multipledispatch                  0.6.0
# mypy                              1.14.1
# mypy_extensions                   1.0.0
# mysql-connector-python            9.4.0
# narwhals                          1.31.0
# navigator-updater                 0.5.1
# nbclient                          0.10.2
# nbconvert                         7.16.6
# nbformat                          5.10.4
# nest_asyncio                      1.6.0
# networkx                          3.4.2
# nltk                              3.9.1
# notebook                          7.3.2
# notebook_shim                     0.2.4
# numba                             0.61.0
# numexpr                           2.10.1
# numpy                             2.1.3
# numpydoc                          1.7.0
# openpyxl                          3.1.5
# overrides                         7.4.0
# packaging                         24.2
# pandas                            2.2.3
# pandocfilters                     1.5.0
# panel                             1.7.0
# param                             2.2.0
# parsel                            1.8.1
# parso                             0.8.4
# partd                             1.4.2
# pathspec                          0.10.3
# patsy                             1.0.1
# pexpect                           4.8.0
# pickleshare                       0.7.5
# pillow                            11.1.0
# pip                               25.1
# pkce                              1.0.3
# pkginfo                           1.12.0
# platformdirs                      4.3.7
# plotly                            5.24.1
# pluggy                            1.5.0
# ply                               3.11
# poyo                              0.5.0
# prometheus_client                 0.21.1
# prompt_toolkit                    3.0.43
# propcache                         0.3.1
# Protego                           0.4.0
# protobuf                          5.29.3
# psutil                            5.9.0
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# py-cpuinfo                        9.0.0
# pyarrow                           19.0.0
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycodestyle                       2.12.1
# pycosat                           0.6.6
# pycparser                         2.21
# pyct                              0.5.0
# pycurl                            7.45.6
# pydantic                          2.10.3
# pydantic_core                     2.27.1
# pydantic-settings                 2.6.1
# PyDispatcher                      2.0.5
# pydocstyle                        6.3.0
# pyerfa                            2.0.1.5
# pyflakes                          3.2.0
# PyGithub                          2.4.0
# Pygments                          2.19.1
# PyJWT                             2.10.1
# pylint                            3.3.5
# pylint-venv                       3.0.3
# pyls-spyder                       0.4.0
# PyNaCl                            1.5.0
# pyodbc                            5.2.0
# pyOpenSSL                         25.0.0
# pyparsing                         3.2.0
# PyQt5                             5.15.10
# PyQt5_sip                         12.13.0
# PyQtWebEngine                     5.15.6
# PySocks                           1.7.1
# pytest                            8.3.4
# python-dateutil                   2.9.0.post0
# python-dotenv                     1.1.0
# python-json-logger                3.2.1
# python-lsp-black                  2.0.0
# python-lsp-jsonrpc                1.1.2
# python-lsp-server                 1.12.2
# python-slugify                    5.0.2
# pytoolconfig                      1.2.6
# pytz                              2024.1
# pyuca                             1.2
# pyviz_comms                       3.0.2
# pywaffle                          1.1.1
# PyWavelets                        1.8.0
# pywin32                           308
# pywin32-ctypes                    0.2.2
# pywinpty                          2.0.15
# PyYAML                            6.0.2
# pyzmq                             26.2.0
# QDarkStyle                        3.2.3
# qstylizer                         0.2.2
# QtAwesome                         1.4.0
# qtconsole                         5.6.1
# QtPy                              2.4.1
# queuelib                          1.6.2
# readchar                          4.0.5
# referencing                       0.30.2
# regex                             2024.11.6
# requests                          2.32.3
# requests-file                     2.1.0
# requests-toolbelt                 1.0.0
# rfc3339_validator                 0.1.4
# rfc3986_validator                 0.1.1
# rich                              13.9.4
# roman-numerals-py                 3.1.0
# rope                              1.13.0
# rpds-py                           0.22.3
# Rtree                             1.0.1
# ruamel.yaml                       0.18.10
# ruamel.yaml.clib                  0.2.12
# ruamel_yaml_conda                 0.17.21
# s3fs                              2025.3.2
# scikit-image                      0.25.0
# scikit-learn                      1.6.1
# scipy                             1.15.3
# Scrapy                            2.12.0
# seaborn                           0.13.2
# semver                            3.0.2
# Send2Trash                        1.8.2
# service-identity                  24.2.0
# setuptools                        72.1.0
# shellingham                       1.5.0
# sip                               6.7.12
# six                               1.17.0
# sklearn-compat                    0.1.3
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   2.2.0
# sortedcontainers                  2.4.0
# soupsieve                         2.5
# Sphinx                            8.2.3
# sphinxcontrib-applehelp           2.0.0
# sphinxcontrib-devhelp             2.0.0
# sphinxcontrib-htmlhelp            2.1.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              2.0.0
# sphinxcontrib-serializinghtml     2.0.0
# spyder                            6.0.7
# spyder-kernels                    3.0.5
# SQLAlchemy                        2.0.39
# stack-data                        0.2.0
# statsmodels                       0.14.4
# streamlit                         1.45.1
# superqt                           0.7.3
# sympy                             1.13.3
# tables                            3.10.2
# tabulate                          0.9.0
# tblib                             3.1.0
# tenacity                          9.0.0
# terminado                         0.17.1
# text-unidecode                    1.3
# textdistance                      4.6.3
# threadpoolctl                     3.5.0
# three-merge                       0.1.1
# tifffile                          2025.2.18
# tinycss2                          1.4.0
# tldextract                        5.1.2
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.13.2
# toolz                             1.0.0
# tornado                           6.5.1
# tqdm                              4.67.1
# traitlets                         5.14.3
# truststore                        0.10.0
# Twisted                           24.11.0
# twisted-iocpsupport               1.0.2
# typer                             0.9.0
# typing_extensions                 4.12.2
# tzdata                            2025.2
# uc-micro-py                       1.0.1
# ujson                             5.10.0
# Unidecode                         1.3.8
# uri-template                      1.3.0
# urllib3                           2.3.0
# w3lib                             2.1.2
# watchdog                          4.0.2
# wcwidth                           0.2.5
# webcolors                         25.10.0
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.1.3
# whatthepatch                      1.0.2
# wheel                             0.45.1
# widgetsnbextension                4.0.13
# win_inet_pton                     1.1.0
# wrapt                             1.17.0
# xarray                            2025.4.0
# xlwings                           0.32.1
# xyzservices                       2022.9.0
# yapf                              0.40.2
# yarl                              1.18.0
# zict                              3.0.0
# zipp                              3.21.0
# zope.interface                    7.1.1
# zstandard                         0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ydata_profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ydata_profiling
#   Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in e:\anaconda\anaconda_install\lib\site-packages (from ydata_profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in e:\anaconda\anaconda_install\lib\site-packages (from ydata_profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in e:\anaconda\anaconda_install\lib\site-packages (from ydata_profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in e:\anaconda\anaconda_install\lib\site-packages (from ydata_profiling) (2.10.3)
# Collecting PyYAML<6.1,>=6.0.3 (from ydata_profiling)
#   Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in e:\anaconda\anaconda_install\lib\site-packages (from ydata_profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in e:\anaconda\anaconda_install\lib\site-packages (from ydata_profiling) (2.1.3)
# Collecting minify-html>=0.15.0 (from ydata_profiling)
#   Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata_profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata_profiling)
#   Downloading phik-0.12.5-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in e:\anaconda\anaconda_install\lib\site-packages (from ydata_profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in e:\anaconda\anaconda_install\lib\site-packages (from ydata_profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in e:\anaconda\anaconda_install\lib\site-packages (from ydata_profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata_profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in e:\anaconda\anaconda_install\lib\site-packages (from ydata_profiling) (0.14.4)
# Collecting typeguard<5,>=4 (from ydata_profiling)
#   Downloading typeguard-4.5.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.2 (from ydata_profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata_profiling)
#   Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite<2,>=1.9 (from ydata_profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<0.63,>=0.60 in e:\anaconda\anaconda_install\lib\site-packages (from ydata_profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in e:\anaconda\anaconda_install\lib\site-packages (from imagehash==4.3.2->ydata_profiling) (1.8.0)
# Requirement already satisfied: pillow in e:\anaconda\anaconda_install\lib\site-packages (from imagehash==4.3.2->ydata_profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\anaconda\anaconda_install\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata_profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda\anaconda_install\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\anaconda_install\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\anaconda_install\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\anaconda\anaconda_install\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda\anaconda_install\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\anaconda\anaconda_install\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda\anaconda_install\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in e:\anaconda\anaconda_install\lib\site-packages (from numba<0.63,>=0.60->ydata_profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\anaconda_install\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata_profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\anaconda_install\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata_profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in e:\anaconda\anaconda_install\lib\site-packages (from phik<0.13,>=0.12.5->ydata_profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\anaconda\anaconda_install\lib\site-packages (from pydantic<3,>=2->ydata_profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in e:\anaconda\anaconda_install\lib\site-packages (from pydantic<3,>=2->ydata_profiling) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in e:\anaconda\anaconda_install\lib\site-packages (from pydantic<3,>=2->ydata_profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\anaconda\anaconda_install\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\anaconda_install\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda\anaconda_install\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\anaconda_install\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (2025.4.26)
# Requirement already satisfied: patsy>=0.5.6 in e:\anaconda\anaconda_install\lib\site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (1.0.1)
# Requirement already satisfied: colorama in e:\anaconda\anaconda_install\lib\site-packages (from tqdm<5,>=4.66.3->ydata_profiling) (0.4.6)
# Collecting typing-extensions>=4.12.2 (from pydantic<3,>=2->ydata_profiling)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in e:\anaconda\anaconda_install\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in e:\anaconda\anaconda_install\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (3.4.2)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling)
#   Downloading puremagic-2.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: six>=1.5 in e:\anaconda\anaconda_install\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata_profiling) (1.17.0)
# Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp313-cp313-win_amd64.whl (678 kB)
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/678.1 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/678.1 kB ? eta -:--:--
#    ----------------------------- -------- 524.3/678.1 kB 542.2 kB/s eta 0:00:01
#    -------------------------------------- 678.1/678.1 kB 550.2 kB/s eta 0:00:00
# Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Downloading typeguard-4.5.2-py3-none-any.whl (36 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.1 MB 470.7 kB/s eta 0:00:06
#    ------ --------------------------------- 0.5/3.1 MB 470.7 kB/s eta 0:00:06
#    ---------- ----------------------------- 0.8/3.1 MB 479.5 kB/s eta 0:00:05
#    ---------- ----------------------------- 0.8/3.1 MB 479.5 kB/s eta 0:00:05
#    ---------- ----------------------------- 0.8/3.1 MB 479.5 kB/s eta 0:00:05
#    ------------- -------------------------- 1.0/3.1 MB 478.6 kB/s eta 0:00:05
#    ---------------- ----------------------- 1.3/3.1 MB 515.1 kB/s eta 0:00:04
#    ---------------- ----------------------- 1.3/3.1 MB 515.1 kB/s eta 0:00:04
#    -------------------- ------------------- 1.6/3.1 MB 546.3 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.8/3.1 MB 581.8 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.8/3.1 MB 581.8 kB/s eta 0:00:03
#    -------------------------- ------------- 2.1/3.1 MB 584.3 kB/s eta 0:00:02
#    -------------------------- ------------- 2.1/3.1 MB 584.3 kB/s eta 0:00:02
#    -------------------------- ------------- 2.1/3.1 MB 584.3 kB/s eta 0:00:02
#    ------------------------------ --------- 2.4/3.1 MB 580.0 kB/s eta 0:00:02
#    ------------------------------ --------- 2.4/3.1 MB 580.0 kB/s eta 0:00:02
#    --------------------------------- ------ 2.6/3.1 MB 572.7 kB/s eta 0:00:01
#    --------------------------------- ------ 2.6/3.1 MB 572.7 kB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 571.1 kB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 571.1 kB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 578.3 kB/s eta 0:00:00
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Downloading puremagic-2.2.0-py3-none-any.whl (71 kB)
# Installing collected packages: minify-html, filetype, typing-extensions, PyYAML, puremagic, multimethod, dacite, typeguard, imagehash, wordcloud, visions, phik, ydata_profiling
#
#    --- ------------------------------------  1/13 [filetype]
#    --- ------------------------------------  1/13 [filetype]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    ------------ ---------------------------  4/13 [puremagic]
#    ------------ ---------------------------  4/13 [puremagic]
#    ------------------ ---------------------  6/13 [dacite]
#    --------------------- ------------------  7/13 [typeguard]
#    ------------------------ ---------------  8/13 [imagehash]
#    --------------------------- ------------  9/13 [wordcloud]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    --------------------------------- ------ 11/13 [phik]
#    --------------------------------- ------ 11/13 [phik]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ---------------------------------------- 13/13 [ydata_profiling]
#
# Successfully installed PyYAML-6.0.3 dacite-1.9.2 filetype-1.2.0 imagehash-4.3.2 minify-html-0.18.1 multimethod-1.12 phik-0.12.5 puremagic-2.2.0 typeguard-4.5.2 typing-extensions-4.15.0 visions-0.8.1 wordcloud-1.9.6 ydata_profiling-4.18.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script filetype.exe is installed in 'C:\Users\User\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script puremagic.exe is installed in 'C:\Users\User\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\User\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pandas_profiling.exe and ydata_profiling.exe are installed in 'C:\Users\User\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = pd.read_csv('titanic_data_updated.csv')
df
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       no   third
# 1              2      yes   first
# 2              3      yes   third
# 3              4      yes   first
# 4              5       no   third
# ..           ...      ...     ...
# 886          887       no  second
# 887          888      yes   first
# 888          889       no   third
# 889          890      yes   first
# 890          891       no   third
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title='Titanic profile report')

profile.to_file('My_titanic_report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 189.34it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- -------------------
# aiobotocore                       2.19.0
# aiohappyeyeballs                  2.4.4
# aiohttp                           3.11.10
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# altair                            5.5.0
# anaconda-anon-usage               0.7.1
# anaconda-auth                     0.8.6
# anaconda-catalogs                 0.2.0
# anaconda-cli-base                 0.5.2
# anaconda-client                   1.13.0
# anaconda-navigator                2.6.6
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# anyio                             4.7.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.3.0
# astroid                           3.3.8
# astropy                           7.0.0
# astropy-iers-data                 0.2025.1.13.0.34.51
# asttokens                         3.0.0
# async-lru                         2.0.4
# asyncssh                          2.17.0
# atomicwrites                      1.4.0
# attrs                             24.3.0
# Automat                           24.8.1
# autopep8                          2.0.4
# babel                             2.16.0
# bcrypt                            4.3.0
# beautifulsoup4                    4.12.3
# binaryornot                       0.4.4
# black                             24.10.0
# bleach                            6.2.0
# blinker                           1.9.0
# bokeh                             3.6.2
# boltons                           24.1.0
# botocore                          1.36.3
# Bottleneck                        1.4.2
# branca                            0.8.2
# Brotli                            1.0.9
# cachetools                        5.5.1
# certifi                           2025.4.26
# cffi                              1.17.1
# chardet                           4.0.0
# charset-normalizer                3.3.2
# click                             8.1.8
# cloudpickle                       3.0.0
# colorama                          0.4.6
# colorcet                          3.1.0
# comm                              0.2.1
# conda                             25.5.1
# conda-anaconda-telemetry          0.1.2
# conda-anaconda-tos                0.2.0
# conda-build                       25.5.0
# conda-content-trust               0.2.0
# conda_index                       0.6.1
# conda-libmamba-solver             25.4.0
# conda-pack                        0.7.1
# conda-package-handling            2.4.0
# conda_package_streaming           0.11.0
# conda-repo-cli                    1.0.165
# conda-token                       0.6.0
# constantly                        23.10.4
# contourpy                         1.3.1
# cookiecutter                      1.7.3
# cryptography                      44.0.1
# cssselect                         1.2.0
# cycler                            0.11.0
# cytoolz                           1.0.1
# dacite                            1.9.2
# dask                              2025.2.0
# dask-expr                         2.0.0
# datashader                        0.18.0
# debugpy                           1.8.11
# decorator                         5.1.1
# defusedxml                        0.7.1
# Deprecated                        1.2.13
# diff-match-patch                  20200713
# dill                              0.3.8
# distributed                       2025.2.0
# distro                            1.9.0
# docstring-to-markdown             0.11
# docutils                          0.21.2
# et_xmlfile                        1.1.0
# evalidate                         2.0.3
# executing                         0.8.3
# fastjsonschema                    2.20.0
# filelock                          3.17.0
# filetype                          1.2.0
# flake8                            7.1.1
# Flask                             3.1.0
# folium                            0.20.0
# fontawesomefree                   6.6.0
# fonttools                         4.55.3
# fqdn                              1.5.1
# frozendict                        2.4.2
# frozenlist                        1.5.0
# fsspec                            2025.3.2
# gitdb                             4.0.7
# GitPython                         3.1.43
# gmpy2                             2.2.1
# greenlet                          3.1.1
# h11                               0.16.0
# h5py                              3.12.1
# HeapDict                          1.0.1
# holoviews                         1.20.2
# httpcore                          1.0.9
# httpx                             0.28.1
# hvplot                            0.11.3
# hyperlink                         21.0.0
# idna                              3.7
# ImageHash                         4.3.2
# imageio                           2.37.0
# imagesize                         1.4.1
# imbalanced-learn                  0.13.0
# importlib_metadata                8.5.0
# incremental                       24.7.2
# inflection                        0.5.1
# iniconfig                         1.1.1
# intake                            2.0.7
# intervaltree                      3.1.0
# ipykernel                         6.29.5
# ipython                           8.30.0
# ipywidgets                        8.1.5
# isoduration                       20.11.0
# isort                             6.0.1
# itemadapter                       0.3.0
# itemloaders                       1.3.2
# itsdangerous                      2.2.0
# jaraco.classes                    3.2.1
# jaraco.context                    0.0.0
# jaraco.functools                  4.1.0
# jedi                              0.19.2
# jellyfish                         1.1.3
# Jinja2                            3.1.6
# jinja2-time                       0.2.0
# jmespath                          1.0.1
# joblib                            1.4.2
# json5                             0.9.25
# jsonpatch                         1.33
# jsonpointer                       2.1
# jsonschema                        4.23.0
# jsonschema-specifications         2023.7.1
# jupyter                           1.1.1
# jupyter_client                    8.6.3
# jupyter-console                   6.6.3
# jupyter_core                      5.7.2
# jupyter-events                    0.12.0
# jupyter-lsp                       2.2.5
# jupyter_server                    2.15.0
# jupyter_server_terminals          0.5.3
# jupyterlab                        4.3.4
# jupyterlab_kernelspy              4.0.0
# jupyterlab-lsp                    5.3.0
# jupyterlab_pygments               0.3.0
# jupyterlab_server                 2.27.3
# jupyterlab_widgets                3.0.13
# keyring                           25.6.0
# kiwisolver                        1.4.8
# lazy_loader                       0.4
# lckr_jupyterlab_variableinspector 3.2.4
# libarchive-c                      5.1
# libmambapy                        2.0.5
# lief                              0.16.4
# linkify-it-py                     2.0.0
# llvmlite                          0.44.0
# lmdb                              1.6.2
# locket                            1.0.0
# lxml                              5.3.0
# lz4                               4.3.2
# Markdown                          3.8
# markdown-it-py                    2.2.0
# MarkupSafe                        3.0.2
# matplotlib                        3.10.0
# matplotlib-inline                 0.1.6
# mccabe                            0.7.0
# mdit-py-plugins                   0.3.0
# mdurl                             0.1.0
# menuinst                          2.2.0
# minify_html                       0.18.1
# mistune                           3.1.2
# mkl_fft                           1.3.11
# mkl_random                        1.2.8
# mkl-service                       2.4.0
# more-itertools                    10.3.0
# mpmath                            1.3.0
# msgpack                           1.0.3
# multidict                         6.1.0
# multimethod                       1.12
# multipledispatch                  0.6.0
# mypy                              1.14.1
# mypy_extensions                   1.0.0
# mysql-connector-python            9.4.0
# narwhals                          1.31.0
# navigator-updater                 0.5.1
# nbclient                          0.10.2
# nbconvert                         7.16.6
# nbformat                          5.10.4
# nest_asyncio                      1.6.0
# networkx                          3.4.2
# nltk                              3.9.1
# notebook                          7.3.2
# notebook_shim                     0.2.4
# numba                             0.61.0
# numexpr                           2.10.1
# numpy                             2.1.3
# numpydoc                          1.7.0
# openpyxl                          3.1.5
# overrides                         7.4.0
# packaging                         24.2
# pandas                            2.2.3
# pandocfilters                     1.5.0
# panel                             1.7.0
# param                             2.2.0
# parsel                            1.8.1
# parso                             0.8.4
# partd                             1.4.2
# pathspec                          0.10.3
# patsy                             1.0.1
# pexpect                           4.8.0
# phik                              0.12.5
# pickleshare                       0.7.5
# pillow                            11.1.0
# pip                               25.1
# pkce                              1.0.3
# pkginfo                           1.12.0
# platformdirs                      4.3.7
# plotly                            5.24.1
# pluggy                            1.5.0
# ply                               3.11
# poyo                              0.5.0
# prometheus_client                 0.21.1
# prompt_toolkit                    3.0.43
# propcache                         0.3.1
# Protego                           0.4.0
# protobuf                          5.29.3
# psutil                            5.9.0
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# puremagic                         2.2.0
# py-cpuinfo                        9.0.0
# pyarrow                           19.0.0
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycodestyle                       2.12.1
# pycosat                           0.6.6
# pycparser                         2.21
# pyct                              0.5.0
# pycurl                            7.45.6
# pydantic                          2.10.3
# pydantic_core                     2.27.1
# pydantic-settings                 2.6.1
# PyDispatcher                      2.0.5
# pydocstyle                        6.3.0
# pyerfa                            2.0.1.5
# pyflakes                          3.2.0
# PyGithub                          2.4.0
# Pygments                          2.19.1
# PyJWT                             2.10.1
# pylint                            3.3.5
# pylint-venv                       3.0.3
# pyls-spyder                       0.4.0
# PyNaCl                            1.5.0
# pyodbc                            5.2.0
# pyOpenSSL                         25.0.0
# pyparsing                         3.2.0
# PyQt5                             5.15.10
# PyQt5_sip                         12.13.0
# PyQtWebEngine                     5.15.6
# PySocks                           1.7.1
# pytest                            8.3.4
# python-dateutil                   2.9.0.post0
# python-dotenv                     1.1.0
# python-json-logger                3.2.1
# python-lsp-black                  2.0.0
# python-lsp-jsonrpc                1.1.2
# python-lsp-server                 1.12.2
# python-slugify                    5.0.2
# pytoolconfig                      1.2.6
# pytz                              2024.1
# pyuca                             1.2
# pyviz_comms                       3.0.2
# pywaffle                          1.1.1
# PyWavelets                        1.8.0
# pywin32                           308
# pywin32-ctypes                    0.2.2
# pywinpty                          2.0.15
# PyYAML                            6.0.3
# pyzmq                             26.2.0
# QDarkStyle                        3.2.3
# qstylizer                         0.2.2
# QtAwesome                         1.4.0
# qtconsole                         5.6.1
# QtPy                              2.4.1
# queuelib                          1.6.2
# readchar                          4.0.5
# referencing                       0.30.2
# regex                             2024.11.6
# requests                          2.32.3
# requests-file                     2.1.0
# requests-toolbelt                 1.0.0
# rfc3339_validator                 0.1.4
# rfc3986_validator                 0.1.1
# rich                              13.9.4
# roman-numerals-py                 3.1.0
# rope                              1.13.0
# rpds-py                           0.22.3
# Rtree                             1.0.1
# ruamel.yaml                       0.18.10
# ruamel.yaml.clib                  0.2.12
# ruamel_yaml_conda                 0.17.21
# s3fs                              2025.3.2
# scikit-image                      0.25.0
# scikit-learn                      1.6.1
# scipy                             1.15.3
# Scrapy                            2.12.0
# seaborn                           0.13.2
# semver                            3.0.2
# Send2Trash                        1.8.2
# service-identity                  24.2.0
# setuptools                        72.1.0
# shellingham                       1.5.0
# sip                               6.7.12
# six                               1.17.0
# sklearn-compat                    0.1.3
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   2.2.0
# sortedcontainers                  2.4.0
# soupsieve                         2.5
# Sphinx                            8.2.3
# sphinxcontrib-applehelp           2.0.0
# sphinxcontrib-devhelp             2.0.0
# sphinxcontrib-htmlhelp            2.1.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              2.0.0
# sphinxcontrib-serializinghtml     2.0.0
# spyder                            6.0.7
# spyder-kernels                    3.0.5
# SQLAlchemy                        2.0.39
# stack-data                        0.2.0
# statsmodels                       0.14.4
# streamlit                         1.45.1
# superqt                           0.7.3
# sympy                             1.13.3
# tables                            3.10.2
# tabulate                          0.9.0
# tblib                             3.1.0
# tenacity                          9.0.0
# terminado                         0.17.1
# text-unidecode                    1.3
# textdistance                      4.6.3
# threadpoolctl                     3.5.0
# three-merge                       0.1.1
# tifffile                          2025.2.18
# tinycss2                          1.4.0
# tldextract                        5.1.2
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.13.2
# toolz                             1.0.0
# tornado                           6.5.1
# tqdm                              4.67.1
# traitlets                         5.14.3
# truststore                        0.10.0
# Twisted                           24.11.0
# twisted-iocpsupport               1.0.2
# typeguard                         4.5.2
# typer                             0.9.0
# typing_extensions                 4.15.0
# tzdata                            2025.2
# uc-micro-py                       1.0.1
# ujson                             5.10.0
# Unidecode                         1.3.8
# uri-template                      1.3.0
# urllib3                           2.3.0
# visions                           0.8.1
# w3lib                             2.1.2
# watchdog                          4.0.2
# wcwidth                           0.2.5
# webcolors                         25.10.0
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.1.3
# whatthepatch                      1.0.2
# wheel                             0.45.1
# widgetsnbextension                4.0.13
# win_inet_pton                     1.1.0
# wordcloud                         1.9.6
# wrapt                             1.17.0
# xarray                            2025.4.0
# xlwings                           0.32.1
# xyzservices                       2022.9.0
# yapf                              0.40.2
# yarl                              1.18.0
# ydata-profiling                   4.18.4
# zict                              3.0.0
# zipp                              3.21.0
# zope.interface                    7.1.1
# zstandard                         0.23.0
# Note: you may need to restart the kernel to use updated packages.
