# %% [markdown]
# # Parameters

# %%
def welcome_message():
    print("Hello phitron")


welcome_message()
# Out:
# Hello phitron

# %%
def welcome_message(user):
    print(f"Hello {user}")

welcome_message("Alamin Refat")
# Out:
# Hello Alamin Refat
