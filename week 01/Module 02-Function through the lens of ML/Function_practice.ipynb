# %% [markdown]
# # Parameters

# %%
def welcome_message():
    print("Hello phitron!")


welcome_message()
# Out:
# Hello phitron!

# %%
def welcome_message(user):
    print(f"Hello {user}")

welcome_message("Alamin Refat!")
# Out:
# Hello Alamin Refat!

# %%
def welcome_message(user="Refat!"):
    print(f"Hello {user}")
welcome_message()
# Out:
# Hello Refat!

# %% [markdown]
# # Doc and Return

# %%
'''
def welcome_message(user="Refat!"):
    print(f"Hello {user}")
welcome_message("Alamin Refat!")
    '''
