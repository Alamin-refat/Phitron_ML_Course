# %% [markdown]
# # ndarray

# %%
arr = [1,2,3]

print(arr*5)

arr = [x*5 for x in arr]

print(arr)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]
# [5, 10, 15]

# %%
import numpy as np
arr1 = np.array([1,2,3])
arr1 = arr1*5
print(arr1)
# Out:
# [ 5 10 15]

# %% [markdown]
# # Ndarray

# %%
import numpy as np

#1D array
arr1 = np.array({1,2,3,4,5})

print(type(arr1))
# Out:
# <class 'numpy.ndarray'>
