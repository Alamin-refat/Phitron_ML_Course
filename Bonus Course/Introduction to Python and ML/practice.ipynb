# %%
print("hello world!")
# Out:
# hello world!

# %%
print("My name is Alamin  Refat")
# Out:
# My name is Alamin  Refat

# %% [markdown]
# # Variables

# %%
number = 456789
print(number)
# Out:
# 456789

# %%
name = "Alamin Refat"
print(name)
# Out:
# Alamin Refat

# %% [markdown]
# # Data Type
