# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic_data_updated.csv')
df
# Out:
#      PassengerId Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1       no   third  ...   7.2500   NaN         S
# 1              2      yes   first  ...  71.2833   C85         C
# 2              3      yes   third  ...   7.9250   NaN         S
# 3              4      yes   first  ...  53.1000  C123         S
# 4              5       no   third  ...   8.0500   NaN         S
# ..           ...      ...     ...  ...      ...   ...       ...
# 886          887       no  second  ...  13.0000   NaN         S
# 887          888      yes   first  ...  30.0000   B42         S
# 888          889       no   third  ...  23.4500   NaN         S
# 889          890      yes   first  ...  30.0000  C148         C
# 890          891       no   third  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]
